# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df_train=pd.read_csv('loan_prediction_train.csv')
df_train.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 204  LP001691    Male     Yes          2  Not Graduate            No
# 295  LP001949    Male     Yes         3+      Graduate           NaN
# 270  LP001888  Female      No          0      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 228  LP001760    Male     NaN        NaN      Graduate            No
# 105  LP001367    Male     Yes          1      Graduate            No
# 313  LP002008    Male     Yes          2      Graduate           Yes
# 308  LP001996    Male      No          0      Graduate            No
# 336  LP002110    Male     Yes          1      Graduate           NaN
# 34   LP001100    Male      No         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 204             3917                0.0       124.0             360.0
# ...

# %%
df_train.drop(columns=['Loan_ID'],inplace=True)

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df_test=pd.read_csv('loan_prediction_test.csv')
df_test.drop(columns=['Loan_ID'],inplace=True)

# %%
df_test
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
# ...

# %%
df_test
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
# ...

# %%
df_train.shape
# Out:
# (614, 12)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
df_train.isna().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df_train.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# # Checking for the duplicated Values

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
df_train['Gender'].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_train.corr(numeric_only=True)
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %% [markdown]
# # Applying Univariate Analysis on the dataset

# %% [markdown]
# ### Applying on the Gender Column

# %%
sns.countplot(data=df_train,x='Gender')
plt.savefig('gender_distribution_univariate.png')

# %% [markdown]
# ### Applying on the Married Column

# %%
df_train['Married'].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
sns.countplot(x=df_train['Married'])
plt.savefig('married_distribution_univariate.png')

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %% [markdown]
# ### Applying on the Dependents Column

# %%
df_train['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
sns.countplot(x=df_train['Dependents'])
plt.savefig('dependents_distribution_univariate.png')

# %% [markdown]
# ### Applyig on the Education Column

# %%
print(f'The total number of counts are \n{df_train['Education'].value_counts()}')
sns.countplot(x=df_train['Education'])
plt.savefig('education_counts.jpg')
plt.show()
# Out:
# The total number of counts are
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
sns.countplot(x=df_train['Self_Employed'])
plt.savefig('self_employed.png')
plt.show()

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
sns.kdeplot(x=df_train['ApplicantIncome'])
plt.savefig('kde_plot_applicant_income.png')
plt.show()

# %%
df_train['ApplicantIncome'].max()
# Out:
# 81000

# %%
df_train['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %%
df_train['ApplicantIncome'].median()
# Out:
# 3812.5

# %% [markdown]
# # Applying Log Trasformation

# %%
df_train['Log_ApplicantIncome']=np.log1p(df_train['ApplicantIncome'])

# %% [markdown]
# ### After Applying Log Transformation

# %%
sns.kdeplot(x=df_train['Log_ApplicantIncome'])
plt.savefig('kde_plot__log_applicant_income.png')
plt.show()

# %%
df_train['ApplicantIncome'].min()
# Out:
# 150

# %%
df_train['ApplicantIncome'].max()
# Out:
# 81000

# %%
sns.boxplot(y=df_train['ApplicantIncome'])
plt.show()

# %%
sns.scatterplot(df_train['ApplicantIncome'])
plt.savefig('scatter_plot_ApplicantIncome_Column.png')
plt.show()

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
sns.kdeplot(x=df_train['CoapplicantIncome'])
plt.savefig('coapplicant.png')
plt.show()

# %%
sns.scatterplot(df_train['CoapplicantIncome'])
plt.savefig('scatter_plot_CoApplicant_Income_Column.png')
plt.show()

# %% [markdown]
# # After Applying the Log Transformation

# %%
df_train['log_CoaaplicantIncome']=np.log1p(df_train['CoapplicantIncome'])

# %%
sns.kdeplot(df_train['log_CoaaplicantIncome'])
plt.savefig('After Aplying Log transformation on the Coaplicant Column.png')
plt.show()

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df_train['LoanAmount'].isna().sum()
# Out:
# 22

# %%
df_train['LoanAmount'].min()
# Out:
# 9.0

# %%
df_train['LoanAmount'].max()
# Out:
# 700.0

# %%
df_train['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
df_train['LoanAmount'].median()
# Out:
# 128.0

# %%
sns.boxplot(y=df_train['LoanAmount'])
plt.savefig('BOx_plot_Loan_Amount_Column.png')
plt.show()

# %% [markdown]
# # Filling Missing VAlues with Imputer and Checling the BoxPLot

# %%
from sklearn.impute import SimpleImputer

si=SimpleImputer(strategy='median')
loan=df_train['LoanAmount']
loan=pd.DataFrame(loan)
si.fit(loan)
# Out:
# SimpleImputer(strategy='median')

# %%
loan
# Out:
#      LoanAmount
# 0           NaN
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [614 rows x 1 columns]

# %%
sns.boxplot(loan)
plt.show()

# %%
loan.mean()
# Out:
# LoanAmount    146.412162
# dtype: float64

# %%
loan.median()
# Out:
# LoanAmount    128.0
# dtype: float64

# %% [markdown]
# # Applying SCatter Plot on the Loan Amount COlumn

# %%
sns.scatterplot(df_train['LoanAmount'])
plt.savefig('scatter_plot_Loan_amonut_Column.png')
plt.show()

# %%
df_train
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df_train['Loan_Amount_Term'].isna().sum()
# Out:
# 14

# %%
sns.scatterplot(df_train['Loan_Amount_Term'])
plt.savefig('scatter_plot_Loan_amonut_Term_Column.png')
plt.show()

# %%
sns.boxplot(df_train['Loan_Amount_Term'])
plt.savefig('box_plot_Loan_amonut_Term_Column.png')
plt.show()

# %%
sns.kdeplot(df_train['Loan_Amount_Term'])
plt.savefig('kde_plot_Loan_amonut_Term_Column.png')
plt.show()

# %%
df_train['Loan_Amount_Term'].mean()
# Out:
# 342.0

# %%
df_train['Loan_Amount_Term'].median()
# Out:
# 360.0

# %% [markdown]
# # PRoperty Area COlumn

# %%
df_train['Property_Area'].isna().sum()
# Out:
# 0

# %%
df_train['Property_Area'].value_counts()
sns.countplot(x=df_train['Property_Area'])
plt.savefig('CountPLot_Property_Area.png')
plt.show()

# %% [markdown]
# # Credit History COlumn

# %%
df_train['Credit_History'].isna().sum()
# Out:
# 50

# %%
df_train['Credit_History'].mode()
# Out:
# 0    1.0
# Name: Credit_History, dtype: float64

# %%
df_train['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
df_train['Credit_History']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 609    1.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Credit_History, Length: 614, dtype: float64

# %%
df_train['Credit_History'].value_counts()
sns.countplot(x=df_train['Credit_History'])
plt.savefig('CountPLot_Credit_History.png')
plt.show()

# %% [markdown]
# # Loan Status COlumn

# %%
df_train['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
sns.countplot(x=df_train['Loan_Status'])
plt.savefig('CountPLot_Loan_Status.png')
plt.show()

# %%
from scipy.stats import probplot

# Create Q-Q plot for exponential distribution
probplot(df_train['Loan_Amount_Term'], dist="norm", plot=plt)
plt.title("Q-Q Plot for Exponential Distribution")
plt.grid(True)
plt.savefig('qqPlot_Loan_Amount_Term.png')
plt.show()

# %% [markdown]
# # Plotting QQ PLOT on the Column

# %%
from scipy.stats import probplot

probplot(df_train['ApplicantIncome'],dist='norm',plot=plt)
plt.title('QQ Plot Applicant Income Column')
plt.savefig('QQ Plot Applicant Income Column.png')
plt.grid()
plt.show()

# %%
probplot(df_train['LoanAmount'],plot=plt)
plt.title('QQ Plot Loan Amount Column')
plt.savefig('QQ Plot Loan Amount Column.png')
plt.grid(True)
plt.show()
